# %%
# !pip install torch==1.4.0
# !pip install transformers==2.9.0
# !pip install pytorch_lightning==0.7.5
# Out:
# Requirement already satisfied: torch==1.4.0 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (1.4.0)
# fastai 1.0.60 requires nvidia-ml-py3, which is not installed.
# You are using pip version 10.0.1, however version 20.2b1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Collecting transformers==2.9.0
#   Downloading https://files.pythonhosted.org/packages/cd/38/c9527aa055241c66c4d785381eaf6f80a28c224cae97daa1f8b183b5fabb/transformers-2.9.0-py3-none-any.whl (635kB)
#     100% |████████████████████████████████| 645kB 3.5MB/s ta 0:00:01
# Requirement already satisfied: tokenizers==0.7.0 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from transformers==2.9.0) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from transformers==2.9.0) (4.42.1)
# Requirement already satisfied: dataclasses; python_version < "3.7" in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from transformers==2.9.0) (0.6)
# Requirement already satisfied: requests in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from transformers==2.9.0) (2.20.0)
# Requirement already satisfied: regex!=2019.12.17 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from transformers==2.9.0) (2020.4.4)
# Requirement already satisfied: sacremoses in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from transformers==2.9.0) (0.0.41)
# Requirement already satisfied: numpy in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from transformers==2.9.0) (1.15.4)
# Requirement already satisfied: sentencepiece in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from transformers==2.9.0) (0.1.85)
# Requirement already satisfied: filelock in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from transformers==2.9.0) (3.0.4)
# Requirement already satisfied: idna<2.8,>=2.5 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from requests->transformers==2.9.0) (2.6)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from requests->transformers==2.9.0) (1.23)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from requests->transformers==2.9.0) (2019.11.28)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from requests->transformers==2.9.0) (3.0.4)
# Requirement already satisfied: click in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from sacremoses->transformers==2.9.0) (6.7)
# Requirement already satisfied: six in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from sacremoses->transformers==2.9.0) (1.11.0)
# Requirement already satisfied: joblib in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from sacremoses->transformers==2.9.0) (0.14.1)
# fastai 1.0.60 requires nvidia-ml-py3, which is not installed.
# Installing collected packages: transformers
#   Found existing installation: transformers 2.10.0
#     Uninstalling transformers-2.10.0:
#       Successfully uninstalled transformers-2.10.0
# Successfully installed transformers-2.9.0
# You are using pip version 10.0.1, however version 20.2b1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Collecting pytorch_lightning==0.7.5
#   Downloading https://files.pythonhosted.org/packages/75/ac/ac03f1f3fa950d96ca52f07d33fdbf5add05f164c1ac4eae179231dfa93d/pytorch_lightning-0.7.5-py3-none-any.whl (233kB)
#     100% |████████████████████████████████| 235kB 587kB/s ta 0:00:011
# Requirement already satisfied: tqdm>=4.41.0 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from pytorch_lightning==0.7.5) (4.42.1)
# Collecting future>=0.17.1 (from pytorch_lightning==0.7.5)
#   Downloading https://files.pythonhosted.org/packages/45/0b/38b06fd9b92dc2b68d58b75f900e97884c45bedd2ff83203d933cf5851c9/future-0.18.2.tar.gz (829kB)
#     100% |████████████████████████████████| 829kB 22.9MB/s a 0:00:011
# Collecting numpy>=1.16.4 (from pytorch_lightning==0.7.5)
#   Downloading https://files.pythonhosted.org/packages/03/27/e35e7c6e6a52fab9fcc64fc2b20c6b516eba930bb02b10ace3b38200d3ab/numpy-1.18.4-cp36-cp36m-manylinux1_x86_64.whl (20.2MB)
#     100% |████████████████████████████████| 20.2MB 616kB/s ta 0:00:011
# Collecting tensorboard>=1.14 (from pytorch_lightning==0.7.5)
#   Downloading https://files.pythonhosted.org/packages/1d/74/0a6fcb206dcc72a6da9a62dd81784bfdbff5fedb099982861dc2219014fb/tensorboard-2.2.2-py3-none-any.whl (3.0MB)
#     100% |████████████████████████████████| 3.0MB 590kB/s ta 0:00:011
# Requirement already satisfied: torch>=1.1 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from pytorch_lightning==0.7.5) (1.4.0)
# Collecting google-auth-oauthlib<0.5,>=0.4.1 (from tensorboard>=1.14->pytorch_lightning==0.7.5)
#   Downloading https://files.pythonhosted.org/packages/7b/b8/88def36e74bee9fce511c9519571f4e485e890093ab7442284f4ffaef60b/google_auth_oauthlib-0.4.1-py2.py3-none-any.whl
# Requirement already satisfied: six>=1.10.0 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from tensorboard>=1.14->pytorch_lightning==0.7.5) (1.11.0)
# Collecting absl-py>=0.4 (from tensorboard>=1.14->pytorch_lightning==0.7.5)
#   Downloading https://files.pythonhosted.org/packages/1a/53/9243c600e047bd4c3df9e69cfabc1e8004a82cac2e0c484580a78a94ba2a/absl-py-0.9.0.tar.gz (104kB)
#     100% |████████████████████████████████| 112kB 36.9MB/s ta 0:00:01
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from tensorboard>=1.14->pytorch_lightning==0.7.5) (0.31.1)
# Collecting markdown>=2.6.8 (from tensorboard>=1.14->pytorch_lightning==0.7.5)
#   Downloading https://files.pythonhosted.org/packages/a4/63/eaec2bd025ab48c754b55e8819af0f6a69e2b1e187611dd40cbbe101ee7f/Markdown-3.2.2-py3-none-any.whl (88kB)
#     100% |████████████████████████████████| 92kB 31.9MB/s ta 0:00:01
# Requirement already satisfied: werkzeug>=0.11.15 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from tensorboard>=1.14->pytorch_lightning==0.7.5) (0.14.1)
# Collecting requests<3,>=2.21.0 (from tensorboard>=1.14->pytorch_lightning==0.7.5)
#   Using cached https://files.pythonhosted.org/packages/1a/70/1935c770cb3be6e3a8b78ced23d7e0f3b187f5cbfab4749523ed65d7c9b1/requests-2.23.0-py2.py3-none-any.whl
# Collecting google-auth<2,>=1.6.3 (from tensorboard>=1.14->pytorch_lightning==0.7.5)
#   Downloading https://files.pythonhosted.org/packages/88/8c/d161e4653a574e2299bc7d1cae14f08db74f828febaf30a1b7e216680085/google_auth-1.16.0-py2.py3-none-any.whl (90kB)
#     100% |████████████████████████████████| 92kB 33.0MB/s ta 0:00:01
# Collecting setuptools>=41.0.0 (from tensorboard>=1.14->pytorch_lightning==0.7.5)
#   Downloading https://files.pythonhosted.org/packages/95/95/f657b6e17f00c3f35b5f68b10e46c3a43af353d8856bd57bfcfb1dbb3e92/setuptools-47.1.1-py3-none-any.whl (583kB)
#     100% |████████████████████████████████| 583kB 28.5MB/s ta 0:00:01
# Collecting protobuf>=3.6.0 (from tensorboard>=1.14->pytorch_lightning==0.7.5)
#   Downloading https://files.pythonhosted.org/packages/28/05/9867ef8eafd12265267bee138fa2c46ebf34a276ea4cbe184cba4c606e8b/protobuf-3.12.2-cp36-cp36m-manylinux1_x86_64.whl (1.3MB)
#     100% |████████████████████████████████| 1.3MB 590kB/s ta 0:00:011
# Collecting tensorboard-plugin-wit>=1.6.0 (from tensorboard>=1.14->pytorch_lightning==0.7.5)
#   Downloading https://files.pythonhosted.org/packages/51/cd/a0c1f9e4582ea64dddf76c1b808b318d01e3b858a51c715bffab1016ecc7/tensorboard_plugin_wit-1.6.0.post3-py3-none-any.whl (777kB)
#     100% |████████████████████████████████| 778kB 29.1MB/s ta 0:00:01
# Collecting grpcio>=1.24.3 (from tensorboard>=1.14->pytorch_lightning==0.7.5)
#   Downloading https://files.pythonhosted.org/packages/f1/23/62d3e82fa4c505f3195315c8a774b2e656b556d174329aa98edb829e48bc/grpcio-1.29.0.tar.gz (19.6MB)
#     100% |████████████████████████████████| 19.6MB 2.5MB/s eta 0:00:01
# Collecting requests-oauthlib>=0.7.0 (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=1.14->pytorch_lightning==0.7.5)
#   Downloading https://files.pythonhosted.org/packages/a3/12/b92740d845ab62ea4edf04d2f4164d82532b5a0b03836d4d4e71c6f3d379/requests_oauthlib-1.3.0-py2.py3-none-any.whl
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from markdown>=2.6.8->tensorboard>=1.14->pytorch_lightning==0.7.5) (1.5.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from requests<3,>=2.21.0->tensorboard>=1.14->pytorch_lightning==0.7.5) (1.23)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from requests<3,>=2.21.0->tensorboard>=1.14->pytorch_lightning==0.7.5) (2019.11.28)
# Requirement already satisfied: chardet<4,>=3.0.2 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from requests<3,>=2.21.0->tensorboard>=1.14->pytorch_lightning==0.7.5) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from requests<3,>=2.21.0->tensorboard>=1.14->pytorch_lightning==0.7.5) (2.6)
# Collecting cachetools<5.0,>=2.0.0 (from google-auth<2,>=1.6.3->tensorboard>=1.14->pytorch_lightning==0.7.5)
#   Downloading https://files.pythonhosted.org/packages/b3/59/524ffb454d05001e2be74c14745b485681c6ed5f2e625f71d135704c0909/cachetools-4.1.0-py3-none-any.whl
# Requirement already satisfied: rsa<4.1,>=3.1.4 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from google-auth<2,>=1.6.3->tensorboard>=1.14->pytorch_lightning==0.7.5) (3.4.2)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<2,>=1.6.3->tensorboard>=1.14->pytorch_lightning==0.7.5)
#   Downloading https://files.pythonhosted.org/packages/95/de/214830a981892a3e286c3794f41ae67a4495df1108c3da8a9f62159b9a9d/pyasn1_modules-0.2.8-py2.py3-none-any.whl (155kB)
#     100% |████████████████████████████████| 163kB 39.3MB/s ta 0:00:01
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=1.14->pytorch_lightning==0.7.5)
#   Downloading https://files.pythonhosted.org/packages/05/57/ce2e7a8fa7c0afb54a0581b14a65b56e62b5759dbc98e80627142b8a3704/oauthlib-3.1.0-py2.py3-none-any.whl (147kB)
#     100% |████████████████████████████████| 153kB 39.4MB/s ta 0:00:01
# Requirement already satisfied: zipp>=0.5 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard>=1.14->pytorch_lightning==0.7.5) (3.0.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from rsa<4.1,>=3.1.4->google-auth<2,>=1.6.3->tensorboard>=1.14->pytorch_lightning==0.7.5) (0.4.8)
# Building wheels for collected packages: future, absl-py, grpcio
#   Running setup.py bdist_wheel for future ... done
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/8b/99/a0/81daf51dcd359a9377b110a8a886b3895921802d2fc1b2397e
#   Running setup.py bdist_wheel for absl-py ... done
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/8e/28/49/fad4e7f0b9a1227708cbbee4487ac8558a7334849cb81c813d
#   Running setup.py bdist_wheel for grpcio ... done
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/ed/06/79/e559ab3b10134903b88e2df2df1b7cc4d3f1a92a46972a09fb
# Successfully built future absl-py grpcio
# fastai 1.0.60 requires nvidia-ml-py3, which is not installed.
# Installing collected packages: future, numpy, requests, oauthlib, requests-oauthlib, cachetools, setuptools, pyasn1-modules, google-auth, google-auth-oauthlib, absl-py, markdown, protobuf, tensorboard-plugin-wit, grpcio, tensorboard, pytorch-lightning
#   Found existing installation: numpy 1.15.4
#     Uninstalling numpy-1.15.4:
#       Successfully uninstalled numpy-1.15.4
#   Found existing installation: requests 2.20.0
#     Uninstalling requests-2.20.0:
#       Successfully uninstalled requests-2.20.0
#   Found existing installation: setuptools 39.1.0
#     Uninstalling setuptools-39.1.0:
#       Successfully uninstalled setuptools-39.1.0
#   Found existing installation: protobuf 3.5.2
#     Uninstalling protobuf-3.5.2:
#       Successfully uninstalled protobuf-3.5.2
# Successfully installed absl-py-0.9.0 cachetools-4.1.0 future-0.18.2 google-auth-1.16.0 google-auth-oauthlib-0.4.1 grpcio-1.29.0 markdown-3.2.2 numpy-1.18.4 oauthlib-3.1.0 protobuf-3.12.2 pyasn1-modules-0.2.8 pytorch-lightning-0.7.5 requests-2.23.0 requests-oauthlib-1.3.0 setuptools-47.1.1 tensorboard-2.2.2 tensorboard-plugin-wit-1.6.0.post3
# You are using pip version 10.0.1, however version 20.2b1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %% [markdown]
# ## Download pretrained model from S3 and unzip in current directory

# %%
import zipfile
import requests, zipfile, io
import os

zip_file_url = "https://datascience-models-ramsri.s3.amazonaws.com/t5_paraphraser.zip"
folder_path = zip_file_url.split("/")[-1].replace(".zip","")

if not os.path.exists(folder_path):
    r = requests.get(zip_file_url)
    z = zipfile.ZipFile(io.BytesIO(r.content))
    z.extractall('./t5_paraphraser')
else:
    print ("Folder available: ",folder_path)
# Out:
# Folder available:  t5_paraphraser

# %%
import torch
from transformers import T5ForConditionalGeneration,T5Tokenizer


def set_seed(seed):
  torch.manual_seed(seed)
  if torch.cuda.is_available():
    torch.cuda.manual_seed_all(seed)

set_seed(42)

model = T5ForConditionalGeneration.from_pretrained('./t5_paraphraser')
tokenizer = T5Tokenizer.from_pretrained('t5-base')

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print ("device ",device)
model = model.to(device)

sentence = "Which course should I take to get started in data science?"
# sentence = "What are the ingredients required to bake a perfect cake?"
# sentence = "What is the best possible approach to learn aeronautical engineering?"
# sentence = "Do apples taste better than oranges in general?"


text =  "paraphrase: " + sentence + " </s>"


max_len = 256

encoding = tokenizer.encode_plus(text,pad_to_max_length=True, return_tensors="pt")
input_ids, attention_masks = encoding["input_ids"].to(device), encoding["attention_mask"].to(device)


# set top_k = 50 and set top_p = 0.95 and num_return_sequences = 3
beam_outputs = model.generate(
    input_ids=input_ids, attention_mask=attention_masks,
    do_sample=True,
    max_length=256,
    top_k=120,
    top_p=0.98,
    early_stopping=True,
    num_return_sequences=10
)


print ("\nOriginal Question ::")
print (sentence)
print ("\n")
print ("Paraphrased Questions :: ")
final_outputs =[]
for beam_output in beam_outputs:
    sent = tokenizer.decode(beam_output, skip_special_tokens=True,clean_up_tokenization_spaces=True)
    if sent.lower() != sentence.lower() and sent not in final_outputs:
        final_outputs.append(sent)

for i, final_output in enumerate(final_outputs):
    print("{}: {}".format(i, final_output))
# Out:
# device  cpu
#
# Original Question ::
# Which course should I take to get started in data science?
#
#
# Paraphrased Questions ::
# 0: What should I learn to become a data scientist?
# 1: How do I get started with data science?
# 2: How would you start a data science career?
# 3: How can I start learning data science?
# 4: How do you get started in data science?
# 5: What's the best course for data science?
# 6: Which course should I start with for data science?
# 7: What courses should I follow to get started in data science?
# 8: What degree should be taken by a data scientist?
# 9: Which course should I follow to become a Data Scientist?
